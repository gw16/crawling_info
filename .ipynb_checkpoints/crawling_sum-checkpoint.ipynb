# %%
import requests
from bs4 import BeautifulSoup 
import re
import urllib.request
import time
from time import sleep

from selenium.webdriver import Chrome  
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium import webdriver

from sqlalchemy import create_engine
import pymysql
import MySQLdb
import mysql.connector

import schedule
import time
from datetime import datetime

# %%
import firebase_admin
from firebase_admin import credentials
from firebase_admin import db
import pandas as pd
import pyrebase

# %%
def browser():

    url ='https://thinkyou.co.kr/contest/sector.asp'

    browser = Chrome('C:/Users/user/Desktop/we_sm/crawling_info/chromedriver.exe')

    delay=3
    browser.implicitly_wait(delay)

    browser.get(url)

    browser.maximize_window()

    body = browser.find_element_by_tag_name('body')

    try :

        browser.find_elements_by_xpath('//*[@id="searchFrm"]/div/dl[1]/dd/p[6]/label/span')[0].click()
        browser.find_elements_by_xpath('//*[@id="searchFrm"]/div/dl[2]/dd/p[1]/label/span')[0].click()
    except:
        pass

    SCROLL_PAUSE_TIME = 0.5
    while True:
        last_height = browser.execute_script('return document.documentElement.scrollHeight')

        for i in range(3):
            body.send_keys(Keys.END)
            time.sleep(SCROLL_PAUSE_TIME)
        new_height = browser.execute_script('return document.documentElement.scrollHeight')
        if new_height == last_height:
            break;

    page = browser.page_source
    soup = BeautifulSoup(page, 'lxml')
    return soup

# %%
def crawling():

    soup = browser()
    len_day = 20
    links_bef = []
    titles_bef = []
    dday_bef = []
    inst_bef = []
    start_bef = []
    end_bef = []
    links_aft = []
    titles_aft = []
    inst_aft = []
    
    for i in range(len_day):
        t = soup.select(' .title > a > dl > dt ')[i].text
        fin = soup.select(' .statNew > p ')[i].text
        if fin == '마감':
            base_url = 'https://thinkyou.co.kr'
            titles_aft.append(soup.select(' .title > a > dl > dt ')[i].text)
            inst_aft.append(soup.select(' .title > a > dl > dd ')[i].text.split(':')[1][1:])
            links_aft.append(base_url + soup.select(' .title > a')[i]['href'][2:])
        else:
            stand = soup.select(' .statNew')[i].text.split('D')[1]
            if stand == '-day':
                num = 0
                base_url = 'https://thinkyou.co.kr'
                titles_bef.append(soup.select(' .title > a > dl > dt ')[i].text)
                inst_bef.append(soup.select(' .title > a > dl > dd ')[i].text.split(':')[1][1:])
                dday_bef.append(num)
                links_bef.append(base_url + soup.select(' .title > a')[i]['href'][2:])
                a = i * 2
                start_bef.append(soup.select(' .etc')[a].text[:8])
                end_bef.append(soup.select(' .etc')[a].text[11:])

            else:
                base_url = 'https://thinkyou.co.kr'
                titles_bef.append(soup.select(' .title > a > dl > dt ')[i].text)
                inst_bef.append(soup.select(' .title > a > dl > dd ')[i].text.split(':')[1][1:])
                dday_bef.append(soup.select(' .statNew')[i].text.split('-')[1])
                links_bef.append(base_url + soup.select(' .title > a')[i]['href'][2:])
                a = i * 2
                start_bef.append(soup.select(' .etc')[a].text[:8])
                end_bef.append(soup.select(' .etc')[a].text[11:])
                
    tabl_data_bef = {'type':"공모전", 'qualification': "대학(원)생",'title':  titles_bef, 'notice': start_bef,  'deadline': end_bef, 'dday':dday_bef, 'sponsor':inst_bef, 'title2': titles_bef,
                     'link':links_bef}
#     df_bef = pd.DataFrame()
#     df_bef['type'] = '공모전'
#     df_bef['qualification'] = '대학(원)생'
    df_bef = pd.DataFrame(tabl_data_bef, columns=['type', 'qualification', 'title', 'notice', 'deadline', 'dday', 'sponsor', 'title2', 'link'])




    return df_bef

# %%
# df1_test = crawling()
# df1_test
# Out:
#   type qualification                  title    notice  deadline dday  \
# 0  공모전        대학(원)생       제9회 엔지니어링산업설계대전   21-02-01  21-03-19   33
# 1  공모전        대학(원)생  2021 ICT 융합 프로젝트 공모전   21-02-01  21-03-31   45
#
#           sponsor                 title2  \
# 0         산업통상자원부       제9회 엔지니어링산업설계대전
# 1  (주)엔티렉스-디바이스마트  2021 ICT 융합 프로젝트 공모전
#
#                                                 link
# 0  https://thinkyou.co.kr/contest/sector_view.asp...
# 1  https://thinkyou.co.kr/contest/sector_view.asp...

# %%
# 모든 크롤링 데이터 합쳐서 중복 제거 하는 부분


# def sum():
#     df1 = crawling()
#     df2 = browser2() #이런식으로 크롤링 데이터 합쳐나가면 됨
#     mid = pd.concat([df1, df2])
#     mid_df = mid.reset_index(drop=True)
#     mid_df['title'] = mid_df['title'].str.strip()
#     fin_df = mid_df.drop_duplicates(['title'], keep='first')
#     fin = fin_df.reset_index(drop = True)
    
#     return fin

# %%
def days_dreams():
    dday_bef = []
    page_num = 1
    while(page_num <=5):        
        url = 'https://www.dreamspon.com/scholarship/scholarship02.html?page=' + str(page_num)
        req = urllib.request.urlopen(url)
        res = req.read()
        soup = BeautifulSoup(res,'html.parser')
        days = soup.select(" .td_day > .count")        
        for i in range(len(days)):
            if 'D+' in str(days[i].text):
                pass
            else:
                
                dday_bef.append((days[i].text).strip("D-"))
        page_num += 1  
    return dday_bef

# %%
def link_test_dreams():
    link_test = []
    page_num = 1
    while(page_num <=5):        
        url = 'https://www.dreamspon.com/scholarship/scholarship02.html?page=' + str(page_num)
        req = urllib.request.urlopen(url)
        res = req.read()
        soup = BeautifulSoup(res,'html.parser')
        contests = soup.find_all("p",class_="title")
        days = soup.select(" .td_day > .count")        
        for i in range(len(days)):
            if 'D+' in str(days[i].text):
                pass
            else:
                link_test.append(str(contests[i]).strip('[<p class="title"><a href="').strip('</a>'))
        page_num += 1  
    return link_test

# %%
def link_dreams(link_test):
    link_bef=[]
    page_num = 1
    for t in range(len(link_test)):
        link_address, title_name = link_test[t].split('">')
        link_ver1 = "https://www.dreamspon.com/" + link_address
        link_bef.append(link_ver1)
    page_num += 1  
    return link_bef

# %%
def titles_dreams(link_test):
    titles_bef = [] # 행사 이름
    page_num = 1
    for t in range(len(link_test)):
        link_address, title_name = link_test[t].split('">')
        titles_bef.append(title_name)
    page_num += 1  
    return titles_bef

# %%
def insts_dreams():
    inst = []
    page_num = 1
    while(page_num <=5):
        url = 'https://www.dreamspon.com/scholarship/scholarship02.html?page=' + str(page_num)
        req = urllib.request.urlopen(url)
        res = req.read()
        soup = BeautifulSoup(res,'html.parser')
        idx = 1
        while(idx<=60):
            if 'D-' in str(soup.select("tr>td")[idx+1].text):
                inst.append(soup.select("tr>td")[idx].text) #       1,5,9, 13
            idx += 4    
        page_num += 1
    return inst

# %%
def s_e_test_dreams(list_adress):

    driver = webdriver.Chrome('C:/Users/user/Desktop/we_sm/crawling_info/chromedriver.exe')
    login_path ='//*[@id="loginForm"]/div[1]/input'

    driver.get("https://www.dreamspon.com/" + list_adress)
    result = driver.switch_to_alert()
    result.accept()

    driver.find_element_by_name('mbr_id').send_keys('rainrain16@hanmail.net')
    driver.find_element_by_name('pwd_in').send_keys('rainrain16')
    driver.find_element_by_xpath(login_path).click()
    #   response = driver.get("https://www.dreamspon.com/" + link_adress)
    sleep(2)

    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')



    crawl_data =soup.select("dl >dd >p>b")[0].text


    start_day, end_day  = (crawl_data).split('~')



    return start_day, end_day

# %%
def s_e_test_dreams(list_adress):

    driver = webdriver.Chrome('C:/Users/user/Desktop/we_sm/crawling_info/chromedriver.exe')
    login_path ='//*[@id="loginForm"]/div[1]/input'

    driver.get(list_adress)
    result = driver.switch_to_alert()
    result.accept()

    driver.find_element_by_name('mbr_id').send_keys('rainrain16@hanmail.net')
    driver.find_element_by_name('pwd_in').send_keys('rainrain16')
    driver.find_element_by_xpath(login_path).click()
    #   response = driver.get("https://www.dreamspon.com/" + link_adress)
    sleep(1)

    html = driver.page_source

    soup = BeautifulSoup(html, 'html.parser')



    crawl_data = str(soup.find_all("li", class_= "day"))
#    crawl_data = (crawl_data.strip('[<li class="day" style="height: 70px; ">')).strip('\n\t')


#    start_day, end_day_ver1  = (crawl_data).split('~')
#    end_day_ver2, end_day_ver3 =  (end_day_ver1).split("<span>D")
    
#    return start_day, end_day_ver1

    
    return crawl_data

# %%
def s_e_days_dreams():
    crawl=[]
    sd_days_list = link_dreams(link_test_dreams())
    
    for i in range(len(sd_days_list)):
        crawl.append(s_e_test_dreams(sd_days_list[i]))
    return crawl

# %%
def s_e_preprocess():
    s_e_pre = s_e_days_dreams()
    for i in range(len(s_e_pre)):
        s_e_pre[i] = (s_e_pre[i].strip('[<li class="day" style="height: 70px; ">')).strip('\n\t')
#         start_day, end_day_ver1  = (crawl_data).split('~')
#         end_day_ver2, end_day_ver3 =  (end_day_ver1).split("<span>D")
    
#    return start_day, end_day_ver1
    return s_e_pre

# %%
def s_e_final():
    s_e_pre = s_e_preprocess()
    start_bef = []
    end_bef = []
    for i in range(len(s_e_pre)):
        if '(1차)' not in s_e_pre[i]:
            start_day, end_day_ver1  = (s_e_pre[i]).split('~')
            end_day_ver2, end_day_ver3 =  (end_day_ver1).split("<span>D")
            start_bef.append(start_day)
            end_bef.append(end_day_ver2)

        else:            
            start_ver1, start_ver2 = (s_e_pre[i]).split('</span><br/>')
            start_ver3, end_ver1 = start_ver1.split('~')
            end_ver2, end_ver3 = end_ver1.split('<span')

            start_ver4 ,end_ver4  = start_ver2.split('~')

            
            end_ver5, end_ver6 = end_ver4.split('<span')

            
            start_bef.append(start_ver3 + "& " + start_ver4)
            end_bef.append("(1차 마감일)"+end_ver2+"& "+"(2차 마감일)"+end_ver5)

#    print(len(start_bef),len(end_bef))
    return start_bef, end_bef

# %%
def final_dreams():
    dday =  days_dreams()
    links = link_dreams(link_test_dreams())
    title = titles_dreams(link_test_dreams())
    start, end = s_e_final()
    inst = insts_dreams()

#     tabl_data_bef = {'title': title, 'notice': start,  'deadline': end, 'dday': dday, 'sponsor': inst, 'title2': title,
#                      'link': links}
#     df_bef = pd.DataFrame(tabl_data_bef, columns=['title', 'notice', 'deadline', 'dday', 'sponsor', 'title2', 'link'])
#     df_bef['type'] = '장학금'
#     df_bef['qualification'] = '대학생'
    
    tabl_data_bef = {'type':"장학금", 'qualification': "대학생",'title': title, 'notice': start,  'deadline': end, 'dday':dday, 'sponsor':inst, 'title2': title,
                     'link':links}
#     df_bef = pd.DataFrame()
#     df_bef['type'] = '공모전'
#     df_bef['qualification'] = '대학(원)생'
    df_bef = pd.DataFrame(tabl_data_bef, columns=['type', 'qualification', 'title', 'notice', 'deadline', 'dday', 'sponsor', 'title2', 'link'])




    return df_bef

# %%
df2_test =  final_dreams()
df2_test
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: use driver.switch_to.alert instead
#   import sys
#    type qualification                       title  \
# 0   공모전           대학생            청년 도시락 대학생 식비 지원
# 1   공모전           대학생               폴얀센 대학생 멘토 장학
# 2   공모전           대학생           용운장학재단 장학 (2021년)
# 3   공모전           대학생        고창장학숙 입사생 선발 (2021년)
# 4   공모전           대학생                  한용교장학재단 장학
# 5   공모전           대학생                문산읍 광문장학회 장학
# 6   공모전           대학생                     흥한재단 장학
# 7   공모전           대학생            음성장학회 장학 (2021년)
# 8   공모전           대학생       몽은장학재단 장학 (2021년 상반기)
# 9   공모전           대학생            제주삼다수 장학 (2021년)
# 10  공모전           대학생               서울군위학사 입사생 선발
# 11  공모전           대학생           우인장학재단 장학 (2021년)
# 12  공모전           대학생         성림교회 장학 (2021년 1학기)
# 13  공모전           대학생            영월장학회 장학 (2021년)
# 14  공모전           대학생             횡성군 글로벌 인재육성 장학
# 15  공모전           대학생                창원시 우파장학회 장학
# 16  공모전           대학생          양양군 인재육성장학 (2021년)
# 17  공모전           대학생         강진군민 장학 (2021년 상반기)
# 18  공모전           대학생           성남시장학회 장학 (2021년)
# 19  공모전           대학생          장흥군 인재육성장학 (2021년)
# 20  공모전           대학생      통영시 저소득 대학생 장학 (2021년)
# 21  공모전           대학생                  영월군 희망복지장학
# 22  공모전           대학생          러시아 정부초청장학 (2021년)
# 23  공모전           대학생           홍천군 무궁화장학 (2021년)
# 24  공모전           대학생     사회리더 대학생 멘토링 장학 (2021년)
# 25  공모전           대학생          괴산군민장학회 장학 (2021년)
# 26  공모전           대학생            담양장학회 장학 (2021년)
# 27  공모전           대학생    GKS 외국인 우수 자비 장학 (2021년)
# 28  공모전           대학생  농어촌 무이자 학자금 융자 (2021년 1학기)
# 51  https://www.dreamspon.com/scholarship/scholars...
# 52  https://www.dreamspon.com/scholarship/scholars...
# 53  https://www.dreamspon.com/scholarship/scholars...
# 54  https://www.dreamspon.com/scholarship/scholars...
# 55  https://www.dreamspon.com/scholarship/scholars...
# 56  https://www.dreamspon.com/scholarship/scholars...

# %%
df1_test
# Out:
#   type qualification                  title    notice  deadline dday  \
# 0  공모전        대학(원)생       제9회 엔지니어링산업설계대전   21-02-01  21-03-19   33
# 1  공모전        대학(원)생  2021 ICT 융합 프로젝트 공모전   21-02-01  21-03-31   45
#
#           sponsor                 title2  \
# 0         산업통상자원부       제9회 엔지니어링산업설계대전
# 1  (주)엔티렉스-디바이스마트  2021 ICT 융합 프로젝트 공모전
#
#                                                 link
# 0  https://thinkyou.co.kr/contest/sector_view.asp...
# 1  https://thinkyou.co.kr/contest/sector_view.asp...

# %% [markdown]
# # 지금부터 테스트

# %%
def tofb():
    df1 = crawling()
    df2 =  final_dreams()

    mid = pd.merge(df1,df2, how='outer')
    mid_df = mid.reset_index(drop=True)
    mid_df['title'] = mid_df['title'].str.strip()
    fin_df = mid_df.drop_duplicates(['title'], keep='first')
    fin = fin_df.reset_index(drop = True)
    

    postdata = fin.to_dict(orient="index")
    config = {
        "apiKey": "AIzaSyDIo8bt7OrCX6KYaxplvUauQdaehcjUo_0",
        "authDomain": "activity-crawling.firebaseapp.com",
        "databaseURL": "https://activity-crawling-default-rtdb.firebaseio.com",
        "projectId": "activity-crawling",
        "storageBucket": "activity-crawling.appspot.com",
        "messagingSenderId": "608978503357",
        "appId": "1:608978503357:web:374a269b8fa1a64888d9d4"}
    firebase = pyrebase.initialize_app(config)
    db = firebase.database()
    db.child().update(postdata)

# %%
tofb()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: use driver.switch_to.alert instead
#   import sys

# %%
#24시간 이후 업데이트

schedule.every().day.at("12:49").do(tofb)
while True:
    schedule.run_pending()
    time.sleep(1)

# %% [markdown]
# # 테스트 끝

# %% [markdown]
# # 추후 수정용이니 건드리지 마세요~

# %%
# df=  final_dreams()
# df

# %%
def job():
    now = datetime.now()
    print(now)
    tofb()
    print("end")


schedule.every().day.at("00:00").do(job)

while True:
    schedule.run_pending()
    time.sleep(1)

# %%
# test_final = tofb()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: use driver.switch_to.alert instead
#   import sys

# %%
# df1 = crawling()
# df1

# %%
# df2 =  final_dreams()
# df2

# %%
df = pd.merge(df1,df2, how='outer')
postdata = df.to_dict(orient="index")
config = {
    "apiKey": "AIzaSyDIo8bt7OrCX6KYaxplvUauQdaehcjUo_0",
    "authDomain": "activity-crawling.firebaseapp.com",
    "databaseURL": "https://activity-crawling-default-rtdb.firebaseio.com",
    "projectId": "activity-crawling",
    "storageBucket": "activity-crawling.appspot.com",
    "messagingSenderId": "608978503357",
    "appId": "1:608978503357:web:374a269b8fa1a64888d9d4"}
firebase = pyrebase.initialize_app(config)
db = firebase.database()
db.child().update(postdata)
# Out:
# {'45': {'dday': 'D-30',
#   'deadline': '(1차 마감일) 2020. 12. 29.& (2차 마감일) 2021. 03. 16.',
#   'link': 'scholarship/scholarship04.html?idx=3167',
#   'notice': '(1차) 2020. 11. 24. & (2차) 2021. 02. 03. ',
#   'qualification': '대학생',
#   'sponsor': '한국장학재단',
#   'title': '국가근로장학 (2021년 1학기)',
#   'title2': '국가근로장학 (2021년 1학기)',
#   'type': '장학금'},
#  '34': {'dday': 'D-9',
#   'deadline': ' 2021. 02. 23.',
#   'link': 'scholarship/scholarship04.html?idx=3380',
#   'notice': '2021. 02. 02. ',
#   'qualification': '대학생',
#   'sponsor': '국립국제교육원',
#   'title': 'GKS 외국인 우수 자비 장학 (2021년)',
#   'title2': 'GKS 외국인 우수 자비 장학 (2021년)',
#   'type': '장학금'},
#  '12': {'dday': 'D-1',
#   'deadline': ' 2021. 02. 15.',
#   'link': 'scholarship/scholarship04.html?idx=3376',
#   'notice': '2021. 01. 15. ',
#   'qualification': '대학생',
#   'sponsor': '광문장학회',
#   'title': '문산읍 광문장학회 장학',
#   'title2': '문산읍 광문장학회 장학',
#   'type': '장학금'},
#  '51': {'dday': 'D-16',
#   'deadline': ' 2021. 03. 02.',
#   'link': 'scholarship/scholarship04.html?idx=3357',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '인천광역시',
#   'title': '인천시 학자금대출 이자지원 (2020년 하반기)',
#   'title2': '인천시 학자금대출 이자지원 (2020년 하반기)',
#   'type': '장학금'},
#  '8': {'dday': 'D-0',
#   'deadline': ' 2021. 02. 14.',
#   'link': 'scholarship/scholarship04.html?idx=3374',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '아이들과미래재단',
#   'title': '폴얀센 대학생 멘토 장학',
#   'title2': '폴얀센 대학생 멘토 장학',
#   'type': '장학금'},
#  '19': {'dday': 'D-3',
#   'deadline': ' 2021. 02. 17.',
#   'link': 'scholarship/scholarship04.html?idx=3350',
#   'notice': '2021. 01. 27. ',
#   'qualification': '대학생',
#   'sponsor': '대한예수교장로회 성림교회',
#   'title': '성림교회 장학 (2021년 1학기)',
#   'title2': '성림교회 장학 (2021년 1학기)',
#   'type': '장학금'},
#  '23': {'dday': 'D-5',
#   'deadline': ' 2021. 02. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3321',
#   'notice': '2021. 01. 18. ',
#   'qualification': '대학생',
#   'sponsor': '양양군인재육성장학회',
#   'title': '양양군 인재육성장학 (2021년)',
#   'title2': '양양군 인재육성장학 (2021년)',
#   'type': '장학금'},
#  '62': {'dday': 'D-75',
#   'deadline': ' 2021. 04. 30.',
#   'link': 'scholarship/scholarship04.html?idx=3384',
#   'notice': '2021. 01. 25. ',
#   'qualification': '대학생',
#   'sponsor': '공무원연금공단',
#   'title': '공무원연금공단 대여학자금 (2021년 1학기)',
#   'title2': '공무원연금공단 대여학자금 (2021년 1학기)',
#   'type': '장학금'},
#  '4': {'dday': 'D-45',
#   'deadline': '21-03-31',
#   'link': 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16631&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=',
#   'notice': '21-02-01',
#   'qualification': '대학(원)생',
#   'sponsor': '(주)엔티렉스-디바이스마트',
#   'title': '2021 ICT 융합 프로젝트 공모전 ',
#   'title2': '2021 ICT 융합 프로젝트 공모전 ',
#   'type': '공모전'},
#  '40': {'dday': 'D-12',
#   'deadline': ' 2021. 02. 26.',
#   'link': 'scholarship/scholarship04.html?idx=3381',
#   'notice': '2021. 02. 08. ',
#   'qualification': '대학생',
#   'sponsor': '화원장학회',
#   'title': '대구 화원읍 장학 (2021년)',
#   'title2': '대구 화원읍 장학 (2021년)',
#   'type': '장학금'},
#  '15': {'dday': 'D-2',
#   'deadline': ' 2021. 02. 16.',
#   'link': 'scholarship/scholarship04.html?idx=3377',
#   'notice': '2021. 01. 25. ',
#   'qualification': '대학생',
#   'sponsor': '몽은장학재단',
#   'title': '몽은장학재단 장학 (2021년 상반기)',
#   'title2': '몽은장학재단 장학 (2021년 상반기)',
#   'type': '장학금'},
#  '11': {'dday': 'D-1',
#   'deadline': ' 2021. 02. 15.',
#   'link': 'scholarship/scholarship04.html?idx=3348',
#   'notice': '2021. 01. 15. ',
#   'qualification': '대학생',
#   'sponsor': '한용교장학재단',
#   'title': '한용교장학재단 장학',
#   'title2': '한용교장학재단 장학',
#   'type': '장학금'},
#  '9': {'dday': 'D-1',
#   'deadline': ' 2021. 02. 15.',
#   'link': 'scholarship/scholarship04.html?idx=3245',
#   'notice': '2020. 12. 13. ',
#   'qualification': '대학생',
#   'sponsor': '용운장학재단',
#   'title': '용운장학재단 장학 (2021년)',
#   'title2': '용운장학재단 장학 (2021년)',
#   'type': '장학금'},
#  '44': {'dday': 'D-30',
#   'deadline': '(1차 마감일) 2020. 12. 29.& (2차 마감일) 2021. 03. 16.',
#   'link': 'scholarship/scholarship04.html?idx=3166',
#   'notice': '(1차) 2020. 11. 24. & (2차) 2021. 02. 03. ',
#   'qualification': '대학생',
#   'sponsor': '한국장학재단',
#   'title': '국가장학금 (2021년 1학기)',
#   'title2': '국가장학금 (2021년 1학기)',
#   'type': '장학금'},
#  '33': {'dday': 'D-9',
#   'deadline': ' 2021. 02. 23.',
#   'link': 'scholarship/scholarship04.html?idx=3355',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '담양장학회',
#   'title': '담양장학회 장학 (2021년)',
#   'title2': '담양장학회 장학 (2021년)',
#   'type': '장학금'},
#  '22': {'dday': 'D-4',
#   'deadline': ' 2021. 02. 18.',
#   'link': 'scholarship/scholarship04.html?idx=3386',
#   'notice': '2021. 02. 16. ',
#   'qualification': '대학생',
#   'sponsor': '우파장학회',
#   'title': '창원시 우파장학회 장학',
#   'title2': '창원시 우파장학회 장학',
#   'type': '장학금'},
#  '56': {'dday': 'D-45',
#   'deadline': ' 2021. 03. 31.',
#   'link': 'scholarship/scholarship04.html?idx=3370',
#   'notice': '2021. 01. 25. ',
#   'qualification': '대학생',
#   'sponsor': '국립국제교육원',
#   'title': '대만장학금 석박사 장학 (2021년)',
#   'title2': '대만장학금 석박사 장학 (2021년)',
#   'type': '장학금'},
#  '55': {'dday': 'D-45',
#   'deadline': ' 2021. 03. 31.',
#   'link': 'scholarship/scholarship04.html?idx=3336',
#   'notice': '2021. 03. 02. ',
#   'qualification': '대학생',
#   'sponsor': '여주시인재육성장학회',
#   'title': '여주시 인재육성장학 (2021년)',
#   'title2': '여주시 인재육성장학 (2021년)',
#   'type': '장학금'},
#  '26': {'dday': 'D-5',
#   'deadline': ' 2021. 02. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3378',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '장흥군인재육성장학회',
#   'title': '장흥군 인재육성장학 (2021년)',
#   'title2': '장흥군 인재육성장학 (2021년)',
#   'type': '장학금'},
#  '50': {'dday': 'D-19',
#   'deadline': ' 2021. 03. 05.',
#   'link': 'scholarship/scholarship04.html?idx=3394',
#   'notice': '2021. 02. 15. ',
#   'qualification': '대학생',
#   'sponsor': '울산광역시남구장학재단',
#   'title': '울산광역시 남구장학 (2021년)',
#   'title2': '울산광역시 남구장학 (2021년)',
#   'type': '장학금'},
#  '37': {'dday': 'D-10',
#   'deadline': ' 2021. 02. 24.',
#   'link': 'scholarship/scholarship04.html?idx=3390',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '무안군승달장학회',
#   'title': '무안군 승달장학 (2021년 상반기)',
#   'title2': '무안군 승달장학 (2021년 상반기)',
#   'type': '장학금'},
#  '61': {'dday': 'D-81',
#   'deadline': '(1차 마감일) 2021. 04. 14.& (2차 마감일) 2021. 05. 06.',
#   'link': 'scholarship/scholarship04.html?idx=3345',
#   'notice': '(1차) 2021. 01. 06. & (2차) 2021. 01. 06. ',
#   'qualification': '대학생',
#   'sponsor': '한국장학재단',
#   'title': '취업 후 상환 생활비대출 (2021년 1학기)',
#   'title2': '취업 후 상환 생활비대출 (2021년 1학기)',
#   'type': '장학금'},
#  '13': {'dday': 'D-1',
#   'deadline': ' 2021. 02. 15.',
#   'link': 'scholarship/scholarship04.html?idx=3400',
#   'notice': '2021. 02. 08. ',
#   'qualification': '대학생',
#   'sponsor': '흥한재단',
#   'title': '흥한재단 장학',
#   'title2': '흥한재단 장학',
#   'type': '장학금'},
#  '46': {'dday': 'D-26',
#   'deadline': ' 2021. 03. 12.',
#   'link': 'scholarship/scholarship04.html?idx=3334',
#   'notice': '2021. 02. 22. ',
#   'qualification': '대학생',
#   'sponsor': '정선장학회',
#   'title': '정선장학회 장학 (2021년)',
#   'title2': '정선장학회 장학 (2021년)',
#   'type': '장학금'},
#  '24': {'dday': 'D-5',
#   'deadline': ' 2021. 02. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3342',
#   'notice': '2021. 01. 25. ',
#   'qualification': '대학생',
#   'sponsor': '강진군민장학재단',
#   'title': '강진군민 장학 (2021년 상반기)',
#   'title2': '강진군민 장학 (2021년 상반기)',
#   'type': '장학금'},
#  '35': {'dday': 'D-10',
#   'deadline': '(1차 마감일) 2021. 01. 13.& (2차 마감일) 2021. 02. 24.',
#   'link': 'scholarship/scholarship04.html?idx=3251',
#   'notice': '(1차) 2021. 01. 04. & (2차) 2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '한국장학재단',
#   'title': '농어촌 무이자 학자금 융자 (2021년 1학기)',
#   'title2': '농어촌 무이자 학자금 융자 (2021년 1학기)',
#   'type': '장학금'},
#  '16': {'dday': 'D-2',
#   'deadline': ' 2021. 02. 16.',
#   'link': 'scholarship/scholarship04.html?idx=3398',
#   'notice': '2021. 02. 08. ',
#   'qualification': '대학생',
#   'sponsor': '제주삼다수재단',
#   'title': '제주삼다수 장학 (2021년)',
#   'title2': '제주삼다수 장학 (2021년)',
#   'type': '장학금'},
#  '5': {'dday': 'D-307',
#   'deadline': '21-12-18',
#   'link': 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16217&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=',
#   'notice': '21-01-18',
#   'qualification': '대학(원)생',
#   'sponsor': '군산대학교 산학협력단',
#   'title': '군산대학교 해상풍력연구원 모니터링 하우스 공모전 ',
#   'title2': '군산대학교 해상풍력연구원 모니터링 하우스 공모전 ',
#   'type': '공모전'},
#  '10': {'dday': 'D-1',
#   'deadline': ' 2021. 02. 15.',
#   'link': 'scholarship/scholarship04.html?idx=3329',
#   'notice': '2021. 01. 19. ',
#   'qualification': '대학생',
#   'sponsor': '고창군',
#   'title': '고창장학숙 입사생 선발 (2021년)',
#   'title2': '고창장학숙 입사생 선발 (2021년)',
#   'type': '장학금'},
#  '59': {'dday': 'D-33',
#   'deadline': ' 2021. 03. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3396',
#   'notice': '2021. 02. 15. ',
#   'qualification': '대학생',
#   'sponsor': '고성향토장학회',
#   'title': '강원도 고성군 향토장학 (2021년)',
#   'title2': '강원도 고성군 향토장학 (2021년)',
#   'type': '장학금'},
#  '48': {'dday': 'D-26',
#   'deadline': ' 2021. 03. 12.',
#   'link': 'scholarship/scholarship04.html?idx=3395',
#   'notice': '2021. 02. 15. ',
#   'qualification': '대학생',
#   'sponsor': '양록장학회',
#   'title': '양구군 양록장학 (2021년)',
#   'title2': '양구군 양록장학 (2021년)',
#   'type': '장학금'},
#  '21': {'dday': 'D-3',
#   'deadline': ' 2021. 02. 17.',
#   'link': 'scholarship/scholarship04.html?idx=3352',
#   'notice': '2021. 02. 15. ',
#   'qualification': '대학생',
#   'sponsor': '횡성인재육성장학회',
#   'title': '횡성군 글로벌 인재육성 장학',
#   'title2': '횡성군 글로벌 인재육성 장학',
#   'type': '장학금'},
#  '54': {'dday': 'D-46',
#   'deadline': ' 2021. 04. 01.',
#   'link': 'scholarship/scholarship04.html?idx=3383',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '국립국제교육원',
#   'title': '라트비아 정부초청장학 (2021년)',
#   'title2': '라트비아 정부초청장학 (2021년)',
#   'type': '장학금'},
#  '43': {'dday': 'D-12',
#   'deadline': ' 2021. 02. 26.',
#   'link': 'scholarship/scholarship04.html?idx=3392',
#   'notice': '2021. 02. 04. ',
#   'qualification': '대학생',
#   'sponsor': '이동우축산장학회',
#   'title': '양구군 이동우축산장학 (2021년)',
#   'title2': '양구군 이동우축산장학 (2021년)',
#   'type': '장학금'},
#  '57': {'dday': 'D-40',
#   'deadline': ' 2021. 03. 26.',
#   'link': 'scholarship/scholarship04.html?idx=3335',
#   'notice': '2021. 01. 04. ',
#   'qualification': '대학생',
#   'sponsor': '제주특별자치도',
#   'title': '제주도 학자금대출 이자지원 (2020년 하반기)',
#   'title2': '제주도 학자금대출 이자지원 (2020년 하반기)',
#   'type': '장학금'},
#  '32': {'dday': 'D-8',
#   'deadline': ' 2021. 02. 22.',
#   'link': 'scholarship/scholarship04.html?idx=3388',
#   'notice': '2021. 02. 03. ',
#   'qualification': '대학생',
#   'sponsor': '괴산군민장학회',
#   'title': '괴산군민장학회 장학 (2021년)',
#   'title2': '괴산군민장학회 장학 (2021년)',
#   'type': '장학금'},
#  '49': {'dday': 'D-22',
#   'deadline': ' 2021. 03. 08.',
#   'link': 'scholarship/scholarship04.html?idx=3333',
#   'notice': '2021. 01. 11. ',
#   'qualification': '대학생',
#   'sponsor': '서울시',
#   'title': '서울시 학자금대출 이자지원 (2020년 하반기)',
#   'title2': '서울시 학자금대출 이자지원 (2020년 하반기)',
#   'type': '장학금'},
#  '6': {'dday': 'D-14',
#   'deadline': '21-02-28',
#   'link': 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16210&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=',
#   'notice': '20-11-04',
#   'qualification': '대학(원)생',
#   'sponsor': 'ZEISS',
#   'title': '2020 ZEISS Microscopy Research Contest ',
#   'title2': '2020 ZEISS Microscopy Research Contest ',
#   'type': '공모전'},
#  '36': {'dday': 'D-10',
#   'deadline': ' 2021. 02. 24.',
#   'link': 'scholarship/scholarship04.html?idx=3389',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '서울제주특별자치도민회',
#   'title': '서울제주도민회 장학 (2021년 1학기)',
#   'title2': '서울제주도민회 장학 (2021년 1학기)',
#   'type': '장학금'},
#  '1': {'dday': 'D-33',
#   'deadline': '21-03-19',
#   'link': 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16808&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=',
#   'notice': '21-02-01',
#   'qualification': '대학(원)생',
#   'sponsor': '산업통상자원부',
#   'title': '제9회 엔지니어링산업설계대전 ',
#   'title2': '제9회 엔지니어링산업설계대전 ',
#   'type': '공모전'},
#  '39': {'dday': 'D-12',
#   'deadline': ' 2021. 02. 26.',
#   'link': 'scholarship/scholarship04.html?idx=3356',
#   'notice': '2021. 02. 15. ',
#   'qualification': '대학생',
#   'sponsor': '강서구장학회',
#   'title': '강서구 지역사회기여 장학 (2021년)',
#   'title2': '강서구 지역사회기여 장학 (2021년)',
#   'type': '장학금'},
#  '17': {'dday': 'D-3',
#   'deadline': ' 2021. 02. 17.',
#   'link': 'scholarship/scholarship04.html?idx=3319',
#   'notice': '2021. 01. 11. ',
#   'qualification': '대학생',
#   'sponsor': '군위군교육발전위원회',
#   'title': '서울군위학사 입사생 선발',
#   'title2': '서울군위학사 입사생 선발',
#   'type': '장학금'},
#  '25': {'dday': 'D-5',
#   'deadline': ' 2021. 02. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3353',
#   'notice': '2021. 01. 25. ',
#   'qualification': '대학생',
#   'sponsor': '성남시장학회',
#   'title': '성남시장학회 장학 (2021년)',
#   'title2': '성남시장학회 장학 (2021년)',
#   'type': '장학금'},
#  '60': {'dday': 'D-81',
#   'deadline': '(1차 마감일) 2021. 04. 14.& (2차 마감일) 2021. 05. 06.',
#   'link': 'scholarship/scholarship04.html?idx=3344',
#   'notice': '(1차) 2021. 01. 06. & (2차) 2021. 01. 06. ',
#   'qualification': '대학생',
#   'sponsor': '한국장학재단',
#   'title': '일반 상환 생활비대출 (2021년 1학기)',
#   'title2': '일반 상환 생활비대출 (2021년 1학기)',
#   'type': '장학금'},
#  '14': {'dday': 'D-2',
#   'deadline': ' 2021. 02. 16.',
#   'link': 'scholarship/scholarship04.html?idx=3349',
#   'notice': '2021. 01. 27. ',
#   'qualification': '대학생',
#   'sponsor': '음성장학회',
#   'title': '음성장학회 장학 (2021년)',
#   'title2': '음성장학회 장학 (2021년)',
#   'type': '장학금'},
#  '47': {'dday': 'D-26',
#   'deadline': ' 2021. 03. 12.',
#   'link': 'scholarship/scholarship04.html?idx=3358',
#   'notice': '2021. 03. 03. ',
#   'qualification': '대학생',
#   'sponsor': '서울시',
#   'title': '서울시 청년월세지원 (2021년)',
#   'title2': '서울시 청년월세지원 (2021년)',
#   'type': '장학금'},
#  '31': {'dday': 'D-8',
#   'deadline': ' 2021. 02. 22.',
#   'link': 'scholarship/scholarship04.html?idx=3354',
#   'notice': '2021. 01. 29. ',
#   'qualification': '대학생',
#   'sponsor': '한국장학재단',
#   'title': '사회리더 대학생 멘토링 장학 (2021년)',
#   'title2': '사회리더 대학생 멘토링 장학 (2021년)',
#   'type': '장학금'},
#  '58': {'dday': 'D-33',
#   'deadline': ' 2021. 03. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3371',
#   'notice': '2021. 02. 08. ',
#   'qualification': '대학생',
#   'sponsor': '진안사랑장학재단',
#   'title': '진안사랑장학 (2021년)',
#   'title2': '진안사랑장학 (2021년)',
#   'type': '장학금'},
#  '53': {'dday': 'D-46',
#   'deadline': ' 2021. 04. 01.',
#   'link': 'scholarship/scholarship04.html?idx=3343',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': 'Nuffic',
#   'title': '네덜란드 유학 오렌지튤립장학 (2021년)',
#   'title2': '네덜란드 유학 오렌지튤립장학 (2021년)',
#   'type': '장학금'},
#  '42': {'dday': 'D-12',
#   'deadline': ' 2021. 02. 26.',
#   'link': 'scholarship/scholarship04.html?idx=3391',
#   'notice': '2021. 02. 08. ',
#   'qualification': '대학생',
#   'sponsor': '삼척향토장학재단',
#   'title': '삼척시 향토장학 (2021년)',
#   'title2': '삼척시 향토장학 (2021년)',
#   'type': '장학금'},
#  '0': {'dday': 'D-82',
#   'deadline': '21-05-07',
#   'link': 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16891&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=',
#   'notice': '21-02-05',
#   'qualification': '대학(원)생',
#   'sponsor': '부산광역시, 부산광역시교육청, (재)부산디자인진흥원',
#   'title': '2021 부산국제디자인어워드 ',
#   'title2': '2021 부산국제디자인어워드 ',
#   'type': '공모전'},
#  '20': {'dday': 'D-3',
#   'deadline': ' 2021. 02. 17.',
#   'link': 'scholarship/scholarship04.html?idx=3351',
#   'notice': '2021. 01. 22. ',
#   'qualification': '대학생',
#   'sponsor': '영월장학회',
#   'title': '영월장학회 장학 (2021년)',
#   'title2': '영월장학회 장학 (2021년)',
#   'type': '장학금'},
#  '27': {'dday': 'D-5',
#   'deadline': ' 2021. 02. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3387',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '통영시',
#   'title': '통영시 저소득 대학생 장학 (2021년)',
#   'title2': '통영시 저소득 대학생 장학 (2021년)',
#   'type': '장학금'},
#  '2': {'dday': 'D-4',
#   'deadline': '21-02-18',
#   'link': 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16769&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=',
#   'notice': '21-01-25',
#   'qualification': '대학(원)생',
#   'sponsor': '한국교육학술정보원, 국토교통부, 세종특별자치시교육청',
#   'title': '스마트시티 국가시범도시 에듀테크 R&D 기업 해커톤 ',
#   'title2': '스마트시티 국가시범도시 에듀테크 R&D 기업 해커톤 ',
#   'type': '공모전'},
#  '38': {'dday': 'D-12',
#   'deadline': ' 2021. 02. 26.',
#   'link': 'scholarship/scholarship04.html?idx=3331',
#   'notice': '2021. 02. 08. ',
#   'qualification': '대학생',
#   'sponsor': '경기도민회장학회',
#   'title': '경기도민회 장학 (2021년)',
#   'title2': '경기도민회 장학 (2021년)',
#   'type': '장학금'},
#  '18': {'dday': 'D-3',
#   'deadline': ' 2021. 02. 17.',
#   'link': 'scholarship/scholarship04.html?idx=3320',
#   'notice': '2021. 01. 01. ',
#   'qualification': '대학생',
#   'sponsor': '우인장학재단',
#   'title': '우인장학재단 장학 (2021년)',
#   'title2': '우인장학재단 장학 (2021년)',
#   'type': '장학금'},
#  '30': {'dday': 'D-6',
#   'deadline': ' 2021. 02. 20.',
#   'link': 'scholarship/scholarship04.html?idx=3379',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '홍천군무궁화장학회',
#   'title': '홍천군 무궁화장학 (2021년)',
#   'title2': '홍천군 무궁화장학 (2021년)',
#   'type': '장학금'},
#  '7': {'dday': 'D-0',
#   'deadline': ' 2021. 02. 14.',
#   'link': 'scholarship/scholarship04.html?idx=3341',
#   'notice': '2021. 01. 18. ',
#   'qualification': '대학생',
#   'sponsor': '기아대책',
#   'title': '청년 도시락 대학생 식비 지원',
#   'title2': '청년 도시락 대학생 식비 지원',
#   'type': '장학금'},
#  '29': {'dday': 'D-6',
#   'deadline': ' 2021. 02. 20.',
#   'link': 'scholarship/scholarship04.html?idx=3330',
#   'notice': '2021. 01. 21. ',
#   'qualification': '대학생',
#   'sponsor': '국립국제교육원',
#   'title': '러시아 정부초청장학 (2021년)',
#   'title2': '러시아 정부초청장학 (2021년)',
#   'type': '장학금'},
#  '41': {'dday': 'D-12',
#   'deadline': ' 2021. 02. 26.',
#   'link': 'scholarship/scholarship04.html?idx=3382',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '옥포경복장학회',
#   'title': '옥포경복장학회 장학',
#   'title2': '옥포경복장학회 장학',
#   'type': '장학금'},
#  '63': {'dday': 'D-262',
#   'deadline': ' 2021. 11. 03.',
#   'link': 'scholarship/scholarship04.html?idx=3385',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '한국예술인복지재단',
#   'title': '예술인 의료비 지원 (2021년)',
#   'title2': '예술인 의료비 지원 (2021년)',
#   'type': '장학금'},
#  '3': {'dday': 'D-45',
#   'deadline': '21-03-31',
#   'link': 'https://thinkyou.co.kr/contest/sector_view.asp?idx=16723&page=1&pagesize=30&serstatus=&serdivision=&serfield=5&sertarget=&serprizeMoney=&seritem=0&searchstr=',
#   'notice': '20-04-01',
#   'qualification': '대학(원)생',
#   'sponsor': '공간세라믹',
#   'title': '공간세라믹 건축상 공모 ',
#   'title2': '공간세라믹 건축상 공모 ',
#   'type': '공모전'},
#  '52': {'dday': 'D-16',
#   'deadline': ' 2021. 03. 02.',
#   'link': 'scholarship/scholarship04.html?idx=3393',
#   'notice': '2021. 02. 01. ',
#   'qualification': '대학생',
#   'sponsor': '한국관광공사',
#   'title': '한국관광공사 여행기자단 선발 (2021년)',
#   'title2': '한국관광공사 여행기자단 선발 (2021년)',
#   'type': '장학금'},
#  '28': {'dday': 'D-5',
#   'deadline': ' 2021. 02. 19.',
#   'link': 'scholarship/scholarship04.html?idx=3399',
#   'notice': '2021. 02. 08. ',
#   'qualification': '대학생',
#   'sponsor': '영월군',
#   'title': '영월군 희망복지장학',
